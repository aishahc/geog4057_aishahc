# %%
import arcpy
import os
pathname = r"C:\Users\Asiha\Documents\Scripts\finals2\finals2"
aprx = arcpy.mp.ArcGISProject(os.path.join(pathname,"finals2.aprx"))
print(aprx.defaultGeodatabase)
# Out:
# C:\Users\Asiha\Documents\Scripts\finals2\finals2\finals2.gdb

# %%
aprx = arcpy.mp.ArcGISProject("CURRENT")
m = aprx.listMaps("final2")[0]
lyr = m.listLayers("no_tax_Tool1")[0]
sym = lyr.symbology
orange = {"RGB": [255, 165, 0, 100]}
if lyr.isFeatureLayer and hasattr(sym, "renderer"):
    sym.renderer.symbol.color = orange
    lyr.symbology = sym

# %%
m = aprx.listMaps("final2")[0]

lyt = aprx.createLayout( 11,8.5, 'INCH', 'f2layout')

def MakeRec_LL(llx, lly, w, h):
    xyRecList = [[llx, lly], [llx, lly+h], [llx+w,lly+h], [llx+w,lly], [llx,lly]]
    array = arcpy.Array([arcpy.Point(*coords) for coords in xyRecList])
    rec = arcpy.Polygon(array)
    return rec

mf = lyt.createMapFrame(MakeRec_LL(0.5,0.5,10,7.5), m, "f2layout")

# %%
naStyle = aprx.listStyleItems('ArcGIS 2D', 'North_Arrow', 'Compass North 1')[0]
na = lyt.createMapSurroundElement(arcpy.Point(9.5,7.5), 'North_Arrow', mf,
                                      naStyle, "Compass North Arrow")
na.elementWidth = 0.5  

sbName = 'Double Alternating Scale Bar 1 Metric'
sbStyle = aprx.listStyleItems('ArcGIS 2D', 'Scale_bar', sbName)[0]
sbEnv = MakeRec_LL(5.5, 0.1, 4, 0.5)
sb = lyt.createMapSurroundElement(sbEnv, 'Scale_bar', mf, sbStyle, 'New Scale Bar')

# %%
legSi = aprx.listStyleItems('ArcGIS 2D', 'LEGEND', 'Legend 3' )[0]
leg = lyt.createMapSurroundElement(arcpy.Point(1,7), 'LEGEND', mf, legSi, 'New Legend Element')
leg.elementWidth = 3
leg.elementHeight = 3
leg.fittingStrategy = 'AdjustFontSize'
leg.columnCount = 1
leg.title = 'No Tax Data'

# %%
lyt.exportToPDF(os.path.join(r"C:\Users\Asiha\Documents\Scripts\finals2", 'project1.pdf'))
# Out:
# 'C:\\Users\\Asiha\\Documents\\Scripts\\finals2\\project1.pdf'
